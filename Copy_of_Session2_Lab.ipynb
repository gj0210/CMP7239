# %% [markdown]
# <a href="https://colab.research.google.com/github/gj0210/CMP7239/blob/main/Copy_of_Session2_Lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Exercise 1**
# # This function expects 3 arguments, first one should your name, 2nd last name and 3rd DOB:

# %%
def register_user(first_name, last_name, dob):
  print(f"Name: {first_name} {last_name}")
  print(f"Date of birth: {dob}")

register_user("jenny", "Roy", "04-08-2001")
# Out:
# Name: jenny Roy
# Date of birth: 04-08-2001

# %% [markdown]
# ## **Exercise 2**

# %%
# This is example for you
i = 1
while i < 6:
  print(i)
  i += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
i=2
while i < 5:
  print(i)
  i += 1
# Out:
# 2
# 3
# 4

# %% [markdown]
#  **Use while with Break**

# %%
i = 1
while i < 6:
  print(i)
  if i == 3:
    break
  i += 1
# Out:
# 1
# 2
# 3

# %%
i = 1
while i < 5:
  print(i)
  if i == 3:
    break
  i += 1
# Out:
# 1
# 2
# 3

# %% [markdown]
# ## **Exercise 3**
# Test if a is greater than b, AND if c is greater than a:
#
# Note: choose the value of variable a, b and c

# %%
a = 2
b = 5
c = 15

if a > b and c > a:
  print("a is greater than b and, c is greater than b")
else:
  print("b is smaller than a and c")
# Out:
# b is smaller than a and c

# %% [markdown]
# ## **Exercise 4**
# Example
# Using the start parameter:
#
# for x in range(2, 6):
#   print(x)

# %%
for x in range(3,9):
  print(x)
# Out:
# 3
# 4
# 5
# 6
# 7
# 8

# %% [markdown]
# **Note:** The range() function defaults to increment the sequence by 1, however it is possible to specify the increment value by adding a third parameter: range(2, 30, 3)

# %% [markdown]
# #**Excercise 5**
#
# Use range to print the value of x with Increment the sequence with 3:

# %%
for x in range(2, 10, 5):
  print(x)
# Out:
# 2
# 7

# %% [markdown]
# # **Excercise 6**
#
# 1. You need to read array 1 and 2. Print their shaps.
# 2. Print the sum, mean, std-value for each array.
# 3. Print addition, division and muliplication of array1 and array2.
#
# *If you stuck review the CMP7239 Session + lab 2 Numpy*
#
#
# array1 = np.array([10, 20, 30, 40])
#
# array2 = np.array([1, 2, 3, 4])

# %%
# Add you code here
import numpy as np

array1 = np.array([110, 20, 30, 40])
array2 = np.array([1,2,3,4])

print("Shape of array1 : ", array1.shape)
print("Shape of array2 : ", array2.shape)

print ("Array1 - sum:", np.sum(array1), "Mean :", np.mean(array1), "std:",np.std(array1))
print ("Array2 - sum:", np.sum(array2), "Mean :", np.mean(array2), "std:",np.std(array2))

print("Addition:", array1 + array2)
print("Division:", array1 / array2)
print("Multiplication:", array1 + array2)
# Out:
# Shape of array1 :  (4,)
# Shape of array2 :  (4,)
# Array1 - sum: 200 Mean : 50.0 std: 35.35533905932738
# Array2 - sum: 10 Mean : 2.5 std: 1.118033988749895
# Addition: [111  22  33  44]
# Division: [110.  10.  10.  10.]
# Multiplication: [111  22  33  44]

# %% [markdown]
# # Below is a step-by-step outline (with explanations) showing how to:
#
# *Make sure to download the (cs_Dataset) before you start and upload it to this notebook*
#
# 1. Read your CSV file into a Pandas DataFrame
#
# 2. Inspect basic structure and summary statistics
#
# 3. Visualise key numerical and categorical features using Matplotlib
#
# Note: replace "your_dataset.csv" with the actual path/name of your CSV file.

# %% [markdown]
# # Below is a step-by-step outline (with explanations) showing how to:
#
# *Make sure to download the (cs_Dataset) before you start and upload it to this notebook*
#
# 1. Read your CSV file into a Pandas DataFrame
#
# 2. Inspect basic structure and summary statistics
#
# 3. Visualise key numerical and categorical features using Matplotlib
#
# Note: replace "your_dataset.csv" with the actual path/name of your CSV file.

# %%
# 1.Import libraries and load the CSV

import pandas as pd
import matplotlib.pyplot as plt

# (Optional) Ensure plots appear inline if you’re using a Jupyter notebook
# %matplotlib inline

# 1.1 Read the CSV into a DataFrame
df = pd.read_csv("cs_Dataset.csv")

# 1.2 Inspect the first few rows
print(df.head())
# Out:
#    duration protocol_type   service flag  src_bytes  dst_bytes      label
# 0         0           tcp      http   SF        181       5450     normal
# 1        10           udp  domain_u   SF        239        486     normal
# 2         2           tcp  ftp_data   S1          0          0  intrusion
# 3        45          icmp     ecr_i   SF       1032          0  intrusion
# 4         5           tcp      smtp  REJ        224       1250     normal

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("/cs_Dataset.csv")
print(df.head())
# Out:
#    duration protocol_type   service flag  src_bytes  dst_bytes      label
# 0         0           tcp      http   SF        181       5450     normal
# 1        10           udp  domain_u   SF        239        486     normal
# 2         2           tcp  ftp_data   S1          0          0  intrusion
# 3        45          icmp     ecr_i   SF       1032          0  intrusion
# 4         5           tcp      smtp  REJ        224       1250     normal

# %% [markdown]
# **Explanation**
#
# pd.read_csv("your_dataset.csv") loads the CSV into a DataFrame called df.
#
# df.head() shows the first 5 rows, so you can verify column names and a few sample values

# %%
# 2. Inspect DataFrame structure
# 2.1 See column names, non-null counts and dtypes
df.info()

# 2.2 Summary statistics for all numerical columns
print(df.describe())

# 2.3 Count unique values in categorical columns (if any)
for col in df.select_dtypes(exclude="number").columns:
    print(f"\nColumn '{col}' value counts:")
    print(df[col].value_counts())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   duration       15 non-null     int64
#  1   protocol_type  15 non-null     object
#  2   service        15 non-null     object
#  3   flag           15 non-null     object
#  4   src_bytes      15 non-null     int64
#  5   dst_bytes      15 non-null     int64
#  6   label          15 non-null     object
# dtypes: int64(3), object(4)
# memory usage: 972.0+ bytes
#         duration    src_bytes   dst_bytes
# count  15.000000    15.000000    15.00000
# mean   10.466667   198.066667   837.60000
# std    12.788760   273.750529  1508.59882
# min     0.000000     0.000000     0.00000
# 25%     1.500000     0.000000     0.00000
# 50%     6.000000   150.000000   100.00000
# 75%    13.500000   242.000000   896.00000
# max    45.000000  1032.000000  5450.00000
#
# ...

# %%
df.info()
print(df.describe())
for col in df.select_dtypes(exclude="number").columns:
 print(f"/ncolumn'{col}'value_counts:")
 print(df[col].value_counts())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   duration       15 non-null     int64
#  1   protocol_type  15 non-null     object
#  2   service        15 non-null     object
#  3   flag           15 non-null     object
#  4   src_bytes      15 non-null     int64
#  5   dst_bytes      15 non-null     int64
#  6   label          15 non-null     object
# dtypes: int64(3), object(4)
# memory usage: 972.0+ bytes
#         duration    src_bytes   dst_bytes
# count  15.000000    15.000000    15.00000
# mean   10.466667   198.066667   837.60000
# std    12.788760   273.750529  1508.59882
# min     0.000000     0.000000     0.00000
# 25%     1.500000     0.000000     0.00000
# 50%     6.000000   150.000000   100.00000
# 75%    13.500000   242.000000   896.00000
# max    45.000000  1032.000000  5450.00000
# ...

# %% [markdown]
# **Explanation**
#
#
# * df.info() tells you how many non-null entries each column has, plus each column’s data type.
# * df.describe() prints count, mean, std, min, max and quartiles for every numerical column.
# * If you have columns that are strings (e.g. "protocol_type", "flag", "label"), using value_counts() on them helps you see how many times each category appears.

# %%
# 3. Visualise key numerical features
# Assuming your dataset has numerical columns such as duration, src_bytes and dst_bytes, you can plot histograms to see their distributions:

# 3.1 List the numerical columns you want to plot
numerical_cols = ["duration", "src_bytes", "dst_bytes"]  # adjust to your actual column names

for col in numerical_cols:
    plt.figure(figsize=(6, 4))
    df[col].hist(bins=10)
    plt.title(f"Histogram of {col}")
    plt.xlabel(col)
    plt.ylabel("Frequency")
    plt.tight_layout()
    plt.show()

# %%
numerical_cols = ["duration", "src_bytes", "dst_byte"]
for col in numerical_cols:
  plt.figure(figsize=(6,4))
  df[col].hist(bins=10)
  plt.title(f"histrogram of {col}")
  plt.xlabel(col)
  plt.ylabel("Frequency")
  plt.tight_layout()
  plt.show()

# %% [markdown]
# **Explanation**
#
# * This creates one histogram per numerical feature.
#
# * Adjust bins=10 (or any integer) to change granularity

# %%
# 4. Visualise categorical‐feature distributions

# If you have categorical columns like "label" (e.g. “normal” vs. “intrusion”) or "protocol_type", "flag", you can use bar charts:


# 4.1 Plot the 'label' distribution
plt.figure(figsize=(5, 3))
label_counts = df["label"].value_counts()
label_counts.plot(kind="bar", color=["green", "red"])
plt.title("Label Distribution")
plt.xlabel("Label")
plt.ylabel("Count")
plt.tight_layout()
plt.show()

# 4.2 Plot 'protocol_type' distribution (if present)
if "protocol_type" in df.columns:
    plt.figure(figsize=(5, 3))
    protocol_counts = df["protocol_type"].value_counts()
    protocol_counts.plot(kind="bar", color="skyblue")
    plt.title("Protocol Type Distribution")
    plt.xlabel("Protocol Type")
    plt.ylabel("Count")
    plt.tight_layout()
    plt.show()

# 4.3 Plot 'flag' distribution (if present)
if "flag" in df.columns:
    plt.figure(figsize=(5, 3))
    flag_counts = df["flag"].value_counts()
    flag_counts.plot(kind="bar", color="orange")
    plt.title("Flag Distribution")
    plt.xlabel("Flag")
    plt.ylabel("Count")
    plt.tight_layout()
    plt.show()

# %%
plt.figure(figsize=(5,3))
label_counts = df["label"].value_counts()
label_counts.plot(kind="bar", color=["violet", "pink"])
plt.title("Label Distribution")
plt.xLabel("Label")
plt.yLabel("Count")
plt.tight_layout()
plt.show()

if "protocol_type" in df.columns:
  plt.figure(figsize=(5,3))
  protocol_counts = df["protocol_type"].value.counts()
  protocol_counts.plot(kind="bar", color="green")
  plt.title("protocol_type Distribution")
  plt.xlabel("protocol_type")
  plt.ylabel("count")
  plt.tight_Layout()
  plt.show()

  if "flag" in df.columns:
    plt.figure(figsize=(5,3))
    flag_counts = df["flag"].value_counts()
    flag_counts.plot(kind="bar", color="red")
    plt.title("flag Distribution")
    plt.xlabel("flag")
    plt.ylabel("count")
    plt.tight_layout()
    plt.show()

# %% [markdown]
# **Explanation**
#
# * Replace column names if yours differ.
#
# * *These* bar plots let students quickly see how many records fall into each category.

# %%
# 5. Scatter-plot relationships between two numeric features

# A scatter plot is helpful to see if there’s any pattern between, say, src_bytes and dst_bytes. We can also colour‐code points by the label column:

plt.figure(figsize=(6, 4))

# Map labels to colours
colour_map = {"normal": "blue", "intrusion": "red"}  # adjust values to match your dataset
point_colours = df["label"].map(colour_map)

plt.scatter(df["src_bytes"], df["dst_bytes"], c=point_colours, alpha=0.7)
plt.title("src_bytes vs. dst_bytes (coloured by label)")
plt.xlabel("src_bytes")
plt.ylabel("dst_bytes")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6,4))
colour_map = {"normal": "blue", "intrusion": "red"}
point_colours = df["label"].map(colour_map)
plt.scatter(df["src_bytes"], df["dst_bytes"], c=point_colours, alpha=0.7, marker='*')
plt.title("src_bytes vs. dst_bytes (coloured by label)")
plt.xlabel("src_bytes")
plt.ylabel("dst_bytes")
plt.tight_layout()
plt.show()

# %% [markdown]
# **Explanation**
# * .map(colour_map) produces a colour for each row based on its label.
#
# * **Blue** points might represent “normal”, red for “intrusion” (or however your data is labelled).

# %%
# 6. Putting it all together
"""
 Below is a complete code snippet you can run in one go (e.g. in a single Python script or Jupyter cell).
 Just be sure to change "your_dataset.csv" and column names as needed

"""

import pandas as pd
import matplotlib.pyplot as plt

# 1. Load the CSV
df = pd.read_csv("cs_Dataset.csv")

# 2. Inspect structure
print("=== DataFrame Info ===")
df.info()
print("\n=== First 5 Rows ===")
print(df.head())

print("\n=== Summary Statistics (Numerical) ===")
print(df.describe())

# 3. Categorical value counts (if any)
for col in df.select_dtypes(exclude="number").columns:
    print(f"\nColumn '{col}' value counts:")
    print(df[col].value_counts())

# 4. Histograms of key numerical features
numerical_cols = ["duration", "src_bytes", "dst_bytes"]  # adjust as needed
for col in numerical_cols:
    plt.figure(figsize=(6, 4))
    df[col].hist(bins=10)
    plt.title(f"Histogram of {col}")
    plt.xlabel(col)
    plt.ylabel("Frequency")
    plt.tight_layout()
    plt.show()

# 5. Bar charts for categorical features
if "label" in df.columns:
    plt.figure(figsize=(5, 3))
    df["label"].value_counts().plot(kind="bar", color=["green", "red"])
    plt.title("Label Distribution")
    plt.xlabel("Label")
    plt.ylabel("Count")
    plt.tight_layout()
    plt.show()

if "protocol_type" in df.columns:
    plt.figure(figsize=(5, 3))
    df["protocol_type"].value_counts().plot(kind="bar", color="skyblue")
    plt.title("Protocol Type Distribution")
    plt.xlabel("Protocol Type")
    plt.ylabel("Count")
    plt.tight_layout()
    plt.show()

if "flag" in df.columns:
    plt.figure(figsize=(5, 3))
    df["flag"].value_counts().plot(kind="bar", color="orange")
    plt.title("Flag Distribution")
    plt.xlabel("Flag")
    plt.ylabel("Count")
    plt.tight_layout()
    plt.show()

# 6. Scatter plot: src_bytes vs. dst_bytes coloured by label
if {"src_bytes", "dst_bytes", "label"}.issubset(df.columns):
    plt.figure(figsize=(6, 4))
    colour_map = {"normal": "blue", "intrusion": "red"}
    plt.scatter(df["src_bytes"], df["dst_bytes"],
                c=df["label"].map(colour_map), alpha=0.7)
    plt.title("src_bytes vs. dst_bytes (coloured by label)")
    plt.xlabel("src_bytes")
    plt.ylabel("dst_bytes")
    plt.tight_layout()
    plt.show()
# Out:
# === DataFrame Info ===
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   duration       15 non-null     int64
#  1   protocol_type  15 non-null     object
#  2   service        15 non-null     object
#  3   flag           15 non-null     object
#  4   src_bytes      15 non-null     int64
#  5   dst_bytes      15 non-null     int64
#  6   label          15 non-null     object
# dtypes: int64(3), object(4)
# memory usage: 972.0+ bytes
#
# === First 5 Rows ===
#    duration protocol_type   service flag  src_bytes  dst_bytes      label
# 0         0           tcp      http   SF        181       5450     normal
# 1        10           udp  domain_u   SF        239        486     normal
# 2         2           tcp  ftp_data   S1          0          0  intrusion
# 3        45          icmp     ecr_i   SF       1032          0  intrusion
# ...

# %% [markdown]
# **Explanation**
#
# 1. Loading the data
#
# * We import pandas (as pd) to handle tabular data easily.
#
# * df = pd.read_csv("your_dataset.csv") reads all columns and rows into a DataFrame.
#
# 2. Inspecting the DataFrame
#
# * df.info() tells us how many rows, non‐null entries, and the data type of each column (e.g. int64, object).
#
# * df.head() prints the first five records so you can see sample values and verify column names.
#
# * df.describe() automatically computes count, mean, standard deviation, min, max, and quartiles for every numerical column.
#
# 3. Counting categorical values
#
# * For any column whose dtype is not numeric (e.g. strings), we call .value_counts() to see how many times each category appears.
#
# 4. Visualising numerical distributions with histograms
#
# * We choose a numerical column (e.g. duration) and call .hist() on it. That breaks the range of values into “bins” and counts how many rows fall into each bin.
#
# * Students should notice whether the data are skewed (most values in one region) or uniform (evenly spread), etc.
#
# 5. Visualising categorical distributions with bar charts
#
# * For columns like label or protocol_type, we again call .value_counts() and then .plot(kind="bar").
#
# * Bar heights show how many samples belong to each category.
#
# 6. Scatter plot for relationship between two numeric columns
#
# * A scatter plot of src_bytes vs. dst_bytes shows each record as a point on a 2D plane.
#
# * Colour‐coding by label (normal vs. intrusion) can reveal whether intrusions tend to have larger source or destination byte counts

# %% [markdown]
# # In you are interested to know about flag.
#
# In many network‐intrusion datasets (e.g. KDD’99 or NSL-KDD), the flag attribute encodes the status of a TCP connection using a two-letter abbreviation. These flags reflect how the TCP handshake and teardown proceeded. Here are some of the most common ones you’ll encounter:
#
# SF (“SYN-FIN”):
#
# The connection was successfully established (via a SYN→SYN-ACK→ACK handshake) and then cleanly closed with a FIN.
#
# In other words, a normal connection that opened and closed without errors.
#
# S0 (“SYN-no reply”):
#
# A SYN packet was sent to initiate a connection, but no reply (SYN-ACK or RST) was received.
#
# This often indicates a port scan or a “half-open” attempt that never completed.
#
# S1 (“SYN-ESTABLISHED-no FIN”):
#
# The SYN→SYN-ACK→ACK handshake was completed, so the connection was established, but it did not terminate via FIN.
#
# In practice, this might signal a connection that remains open or was abruptly dropped on one side.
#
# REJ (“REJECTED”):
#
# A SYN packet was sent and the target explicitly responded with a TCP RST (reset), rejecting the connection.
#
# Typically indicates an attempt to connect to a closed port or a service that refused the session.
#
# S2 / S3 (less common):
#
# S2: SYN→SYN-ACK handshake succeeded, but the connection was reset by the originator (no FIN).
#
# S3: SYN→SYN-ACK handshake succeeded, but the connection was reset by the responder (no FIN).
#
# SH (“SYN-RST-FIN”):
#
# A connection that was established normally (SYN handshake) but then both sides sent a reset (RST) or FIN in quick succession.
#
# Usually indicates an abnormal or forced termination

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 1. Load the CSV
df = pd.read_csv("/cs_Dataset.csv")

# 2. Inspect structure
print("=== DataFrame Info ===")
df.info()
print("\n=== First 5 Rows ===")
print(df.head())

print("\n=== Summary Statistics (Numerical) ===")
print(df.describe())

# 3. Categorical value counts (if any)
for col in df.select_dtypes(exclude="number").columns:
    print(f"\nColumn '{col}' value counts:")
    print(df[col].value_counts())

# 4. Histograms of key numerical features
numerical_cols = ["duration", "src_bytes", "dst_bytes"]  # adjust as needed
for col in numerical_cols:
    plt.figure(figsize=(6, 4))
    df[col].hist(bins=10)
    plt.title(f"Histogram of {col}")
    plt.xlabel(col)
    plt.ylabel("Frequency")
    plt.tight_layout()
    plt.show()

# 5. Bar charts for categorical features
if "label" in df.columns:
    plt.figure(figsize=(5, 3))
    df["label"].value_counts().plot(kind="bar", color=["brown", "red"]) # Updated colors
    plt.title("Label Distribution")
    plt.xlabel("Label")
    plt.ylabel("Count")
    plt.tight_layout()
    plt.show()

if "protocol_type" in df.columns:
    plt.figure(figsize=(5, 3))
    df["protocol_type"].value_counts().plot(kind="bar", color="pink")
    plt.title("Protocol Type Distribution")
    plt.xlabel("Protocol Type")
    plt.ylabel("Count")
    plt.tight_layout()
    plt.show()

if "flag" in df.columns:
    plt.figure(figsize=(5, 3))
    df["flag"].value_counts().plot(kind="bar", color="orange")
    plt.title("Flag Distribution")
    plt.xlabel("Flag")
    plt.ylabel("Count")
    plt.tight_layout()
    plt.show()

# 6. Scatter plot: src_bytes vs. dst_bytes coloured by label
if {"src_bytes", "dst_bytes", "label"}.issubset(df.columns):
    plt.figure(figsize=(6, 4))
    colour_map = {"normal": "blue", "intrusion": "red"} # Updated colors
    plt.scatter(df["src_bytes"], df["dst_bytes"],
                c=df["label"].map(colour_map), alpha=0.7, marker='*') # Updated marker
    plt.title("src_bytes vs. dst_bytes (coloured by label)")
    plt.xlabel("src_bytes")
    plt.ylabel("dst_bytes")
    plt.tight_layout()
    plt.show()
# Out:
# === DataFrame Info ===
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   duration       15 non-null     int64
#  1   protocol_type  15 non-null     object
#  2   service        15 non-null     object
#  3   flag           15 non-null     object
#  4   src_bytes      15 non-null     int64
#  5   dst_bytes      15 non-null     int64
#  6   label          15 non-null     object
# dtypes: int64(3), object(4)
# memory usage: 972.0+ bytes
#
# === First 5 Rows ===
#    duration protocol_type   service flag  src_bytes  dst_bytes      label
# 0         0           tcp      http   SF        181       5450     normal
# 1        10           udp  domain_u   SF        239        486     normal
# 2         2           tcp  ftp_data   S1          0          0  intrusion
# 3        45          icmp     ecr_i   SF       1032          0  intrusion
# ...
